# %% [markdown]
# # Dictionay Practice

# %% [markdown]
# # Problem 1 – Creating Your First Dictionary
#
# Create a dictionary named `favorite_colors` that stores the favorite colors of three friends:
#
# - Alice → "blue"
# - Bob → "green"
# - Carol → "red"
#
# Print the dictionary to verify it looks correct.

# %%
favorite_colors = {
    "Alice": "blue",
    "Bob": "green",
    "Carol": "red"
}

print(favorite_colors)
# Out:
# {'Alice': 'blue', 'Bob': 'green', 'Carol': 'red'}

# %% [markdown]
# # Problem 2 – Accessing Values by Keys
#
# Using the `favorite_colors` dictionary from Problem 1:
#
# - Print Bob’s favorite color by accessing it with his name as the key.
# - Try to access "Dave" (who is not in the dictionary). What happens?

# %%
favorite_colors = {
    "Alice": "blue",
    "Bob": "green",
    "Carol": "red"
}

print(favorite_colors["Bob"])
print(favorite_colors["Dave"])

# It causes a KeyError.
# Out:
# green
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 8
#       4     "Carol": "red"
#       5 }
#       6
#       7 print(favorite_colors["Bob"])
# ----> 8 print(favorite_colors["Dave"])
#       9
#      10 # It causes a KeyError.
#
# KeyError: 'Dave'

# %% [markdown]
# # Problem 3 – Adding and Removing Entries
#
# You just made a new friend, Eve, whose favorite color is purple.
#
# - Add Eve to the `favorite_colors` dictionary.
# - Then, suppose Alice moved away — remove Alice from the dictionary.
# - Print the updated dictionary.

# %%
favorite_colors = {
    "Alice": "blue",
    "Bob": "green",
    "Carol": "red"
}

favorite_colors["Eve"] = "purple"
del favorite_colors["Alice"]
print(favorite_colors)
# Out:
# {'Bob': 'green', 'Carol': 'red', 'Eve': 'purple'}

# %% [markdown]
# # Problem 4 – Dictionaries vs. Lists
#
# You have two collections of email addresses:

# %%
# As a list
emails_list = ["bob@gmail.com", "carol@gmail.com", "eve@gmail.com"]

# As a dictionary
emails_dict = {
    "Bob": "bob@gmail.com",
    "Carol": "carol@gmail.com",
    "Eve": "eve@gmail.com"
}

# %% [markdown]
# Write code to get Carol’s email from the list and then from the dictionary.
#
# Which one feels easier, and why?

# %%
emails_list = ["bob@gmail.com", "carol@gmail.com", "eve@gmail.com"]

emails_dict = {
    "Bob": "bob@gmail.com",
    "Carol": "carol@gmail.com",
    "Eve": "eve@gmail.com"
}

print(emails_list[1])
print(emails_dict["Carol"])

#I feel dictionary is easier because I don't have to remember the index.
# Out:
# carol@gmail.com
# carol@gmail.com

# %% [markdown]
# # Problem 5 – Iterating with Keys, Values, and Items
#
# Using the `emails_dict` above:
# - Print all the names (keys) using a loop.
# - Print all the email addresses (values) using a loop.
# - Write a loop with items() that prints messages like:
# ```
# Bob’s email is bob@gmail.com
# Carol’s email is carol@gmail.com
# Eve’s email is eve@gmail.com
# ```

# %%
emails_dict = {
    "Bob": "bob@gmail.com",
    "Carol": "carol@gmail.com",
    "Eve": "eve@gmail.com"
}

for name in emails_dict.keys():
    print(name)

for email in emails_dict.values():
    print(email)

for name, email in emails_dict.items():
    print(f"{name}'s email is {email}")
# Out:
# Bob
# Carol
# Eve
# bob@gmail.com
# carol@gmail.com
# eve@gmail.com
# Bob's email is bob@gmail.com
# Carol's email is carol@gmail.com
# Eve's email is eve@gmail.com
